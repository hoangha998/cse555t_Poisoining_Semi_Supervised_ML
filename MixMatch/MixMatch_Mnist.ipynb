# %%
# !pip install progress
# !pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for progress: filename=progress-1.6-py3-none-any.whl size=9630 sha256=07c795cc12babf2a4b50670dac135d6483f9e71c1f091aa9e9610f683ecc2abf
#   Stored in directory: /root/.cache/pip/wheels/4c/9b/0a/a78ff56725af3ef70792f9ed0f8dbbc4c0315edc62cbc4a6b8
# Successfully built progress
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 6.0 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
print("changed to:", os.getcwd())
# Out:
# changed to: /content

# %%
import os
print("curren directory:", os.getcwd())
BASE_DIR = '/content/drive/MyDrive/AdversarialAI/MixMatch'
FIXMATCH_DIR = BASE_DIR + ""
os.chdir(FIXMATCH_DIR)
print("changed to:", os.getcwd())
# Out:
# curren directory: /content
# changed to: /content/drive/.shortcut-targets-by-id/1BxAF26QUrD7Hm1djsTbhnWfl_noLdxLZ/MixMatch

# %%
mal = 2
source = 6
N = 150
resume = f"./result/mnist_{N}poison_{mal}_{source}_mixmatch_model_best.pth.tar"

# %%
# !python3 train_mixmatch.py --train-iteration 4096 --epochs 15 --batch-size 64 --dataset mnist --poison-size {N} --label-mali {mal} --label-source {source} --resume {resume}
# Out:
# ['/content/drive/.shortcut-targets-by-id/1BxAF26QUrD7Hm1djsTbhnWfl_noLdxLZ/MixMatch', '/content/drive/MyDrive/AdversarialAI/Poisoner', '/env/python', '/usr/lib/python39.zip', '/usr/lib/python3.9', '/usr/lib/python3.9/lib-dynload', '/usr/local/lib/python3.9/dist-packages', '/usr/lib/python3/dist-packages', '/content/drive/.shortcut-targets-by-id/1BxAF26QUrD7Hm1djsTbhnWfl_noLdxLZ/MixMatch/utils/progress', './']
# ==> Preparing mnist
# Getting MNIST | Subset size, labeled size, test size = [30000, 200, 4000]
# labeled, unlabeled, test sizes: [200, 29800, 3600]
# malicious: Two , target: Six
# x_star: <class 'numpy.ndarray'>
# x_target: <class 'numpy.ndarray'>
# Lossy conversion from float32 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# target and malicious images saved to ./data/latest_poison_mnist_2_6_150
# ...
