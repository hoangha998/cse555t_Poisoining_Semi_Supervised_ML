# %%
# !pip install progress
# !pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for progress: filename=progress-1.6-py3-none-any.whl size=9630 sha256=059c6df36f1a6ad1f5e1e620ab74234c6cd937886d5a5feb879b23e309514f4e
#   Stored in directory: /root/.cache/pip/wheels/bb/01/5a/c916509df9b12c6465864251dbe826def8e31a16fa7da54f08
# Successfully built progress
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 KB 3.3 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
print("curren directory:", os.getcwd())
BASE_DIR = '/content/drive/MyDrive/AdversarialAI/'
FIXMATCH_DIR = BASE_DIR + "MixMatch"
os.chdir(FIXMATCH_DIR)
print("changed to:", os.getcwd())
# Out:
# curren directory: /content
# changed to: /content/drive/.shortcut-targets-by-id/1rq7ZwO6n9Qq8z-u9Ls5ROqESUr9unPFF/AdversarialAI/MixMatch

# %%
# !python3 train.py --train-iteration 4096 --epochs 50
# Out:
# ==> Preparing cifar10
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# #Labeled: 250 #Unlabeled: 44750 #Val: 5000
# ==> creating WRN-28-2
#     Total params: 1.47M
#
# Epoch: [1 | 50] LR: 0.002000
# Training |################################| (2048/2048) Data: 0.020s | Batch: 0.127s | Total: 0:04:20 | ETA: 0:00:01 | Loss: 1.0378 | Loss_x: 1.0291 | Loss_u: 0.0116 | W: 0.7496
# Train Stats |################################| (3/3) Data: 0.009s | Batch: 0.022s | Total: 0:00:00 | ETA: 0:00:01 | Loss: 0.4193 | top1:  99.4792 | top5:  100.0000
# Valid Stats |################################| (79/79) Data: 0.001s | Batch: 0.010s | Total: 0:00:00 | ETA: 0:00:01 | Loss: 1.7245 | top1:  40.4600 | top5:  86.3000
# Test Stats  |################################| (157/157) Data: 0.001s | Batch: 0.009s | Total: 0:00:01 | ETA: 0:00:01 | Loss: 1.7166 | top1:  40.6500 | top5:  87.1100
#
# Epoch: [2 | 50] LR: 0.002000
# ...
